# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib as plt
# %matplotlib inline

# %%
G = nx.read_gpickle("../data/co-authorship_graph.pkl")

# %%
links = G.edges()

# %%
G_sub = G.subgraph(np.unique(np.array(links[:10]).flatten()))

# %%
nx.draw_networkx(G_sub)
# Out:
# /Users/watarukudo/.pyenv/versions/3.6.0/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:511: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /Users/watarukudo/.pyenv/versions/3.6.0/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:532: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:
# /Users/watarukudo/.pyenv/versions/3.6.0/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:712: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(label):
